# %%
import os
os.chdir('../OneDrive/Desktop/Data Mining II/Soccer-Scouting')

# %%
import os
os.listdir()
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  'LICENSE',
#  'player_data_final.csv',
#  'README.md',
#  'Recommender.ipynb',
#  'Web_Scraper.ipynb']

# %%
import pandas as pd
from sklearn import preprocessing
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.neighbors import NearestNeighbors
sns.set(style="white")

# %%
df = pd.read_csv('player_data_final.csv')

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'OVA', 'POT', 'Team & Contract', 'ID', 'Height',
#        'Weight', 'foot', 'BOV', 'BP', 'Growth', 'Joined', 'Loan Date End',
#        'Value', 'Wage', 'Release Clause', 'Attacking', 'Crossing', 'Finishing',
#        'Heading Accuracy', 'Short Passing', 'Volleys', 'Skill', 'Dribbling',
#        'Curve', 'FK Accuracy', 'Long Passing', 'Ball Control', 'Movement',
#        'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance',
#        'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots',
#        'Mentality', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Defending', 'Marking', 'Standing Tackle',
#        'Sliding Tackle', 'Goalkeeping', 'GK Diving', 'GK Handling',
#        'GK Kicking', 'GK Positioning', 'GK Reflexes', 'Total', 'Base Stats',
#        'W/F', 'SM', 'A/W', 'D/W', 'IR', 'PAC', 'SHO', 'PAS', 'DRI', 'DEF',
#        'PHY'],
#       dtype='object')

# %%
df.Wage
# Out:
# 0          €3K
# 1           €0
# 2         €10K
# 3         €51K
# 4         €31K
#          ...
# 20095     €45K
# 20096    €145K
# 20097     €11K
# 20098    €230K
# 20099     €37K
# Name: Wage, Length: 20100, dtype: object

# %%
df= df[df.OVA >70]

# %%
df.reset_index(inplace=True)
df.drop('index',axis=1,inplace=True)
df.drop_duplicates('Name',inplace=True)

# %%
df.head()
# Out:
#                     Name  Age  OVA  POT                  Team & Contract  \
# 0           G. Buffon GK   43   80   80              Parma 2021 ~ 2023
# 1         18 Kaká CAM CF   35   80   80                    Brazil Free
# 2   Yeremy Pino RM LM ST   18   75   87      Villarreal CF 2020 ~ 2027
# 3               Pedri CM   18   81   91       FC Barcelona 2020 ~ 2026
# 4         C. Kelleher GK   22   71   79          Liverpool 2017 ~ 2022
#
#        ID Height Weight   foot  BOV  ... SM     A/W     D/W IR PAC SHO PAS  \
# 0    1179  192cm   92kg  Right   80  ...  1  Medium  Medium  4  76  73  70
# 1  138449  186cm   83kg  Right   78  ...  4    High  Medium  3  62  76  79
# 2  259377  172cm   60kg  Right   76  ...  3    High     Low  1  76  68  72
# 3  251854  174cm   61kg  Right   83  ...  4    High    High  2  78  65  79
# 4  240913  188cm   74kg  Right   71  ...  1  Medium  Medium  1  71  69  73
#
#    DRI  DEF  PHY
# 0   76   34   90
# 1   78   30   58
# 2   76   31   50
# 3   84   66   63
# 4   73   41   68
#
# [5 rows x 71 columns]

# %%
df = df.fillna(df.mean())

# %%
df['Value']=df['Value'].map(lambda x: x.lstrip('€').rstrip('KM')).astype('float64')

# %%
df['Height']=df['Height'].map(lambda x:x.rstrip('cm')).astype('float64')

# %%
df['Weight']=df['Weight'].map(lambda x: x.rstrip('kg')).astype('float64')

# %%
df['foot']=df['foot'].astype('category')

# %%
df['BP'] = df['BP'].astype('category')

# %%
df['Joined']=df['Joined'].astype('datetime64')

# %%
df['Wage']=df['Wage'].map(lambda x: x.lstrip('€').rstrip('K')).astype('float64')

# %%
df['Release Clause']=df['Release Clause'].map(lambda x: x.lstrip('€').rstrip('KM')).astype('float64')

# %%
df['A/W'] =df['A/W'].astype('category')

# %%
df['D/W'] =df['D/W'].astype('category')

# %%
df['foot'] = df['foot'].cat.codes
df['BP'] = df['BP'].cat.codes
df['A/W'] = df['A/W'].cat.codes
df['D/W'] = df['D/W'].cat.codes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3355 entries, 0 to 3590
# Data columns (total 71 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              3355 non-null   object
#  1   Age               3355 non-null   int64
#  2   OVA               3355 non-null   int64
#  3   POT               3355 non-null   int64
#  4   Team & Contract   3355 non-null   object
#  5   ID                3355 non-null   int64
#  6   Height            3355 non-null   float64
#  7   Weight            3355 non-null   float64
#  8   foot              3355 non-null   int8
#  9   BOV               3355 non-null   int64
#  10  BP                3355 non-null   int8
#  11  Growth            3355 non-null   int64
#  12  Joined            3336 non-null   datetime64[ns]
#  13  Loan Date End     310 non-null    object
#  14  Value             3355 non-null   float64
#  15  Wage              3355 non-null   float64
#  16  Release Clause    3355 non-null   float64
#  17  Attacking         3355 non-null   int64
#  18  Crossing          3355 non-null   int64
#  19  Finishing         3355 non-null   int64
#  20  Heading Accuracy  3355 non-null   int64
#  21  Short Passing     3355 non-null   int64
#  22  Volleys           3355 non-null   float64
#  23  Skill             3355 non-null   int64
#  24  Dribbling         3355 non-null   int64
#  25  Curve             3355 non-null   float64
#  26  FK Accuracy       3355 non-null   int64
#  27  Long Passing      3355 non-null   int64
#  28  Ball Control      3355 non-null   int64
#  29  Movement          3355 non-null   int64
#  30  Acceleration      3355 non-null   int64
#  31  Sprint Speed      3355 non-null   int64
#  32  Agility           3355 non-null   float64
#  33  Reactions         3355 non-null   int64
#  34  Balance           3355 non-null   float64
#  35  Power             3355 non-null   int64
#  36  Shot Power        3355 non-null   int64
#  37  Jumping           3355 non-null   float64
#  38  Stamina           3355 non-null   int64
#  39  Strength          3355 non-null   int64
#  40  Long Shots        3355 non-null   int64
#  41  Mentality         3355 non-null   int64
#  42  Aggression        3355 non-null   int64
#  43  Interceptions     3355 non-null   float64
#  44  Positioning       3355 non-null   float64
#  45  Vision            3355 non-null   float64
#  46  Penalties         3355 non-null   int64
#  47  Composure         3355 non-null   float64
#  48  Defending         3355 non-null   int64
#  49  Marking           3355 non-null   int64
#  50  Standing Tackle   3355 non-null   int64
#  51  Sliding Tackle    3355 non-null   float64
#  52  Goalkeeping       3355 non-null   int64
#  53  GK Diving         3355 non-null   int64
#  54  GK Handling       3355 non-null   int64
#  55  GK Kicking        3355 non-null   int64
#  56  GK Positioning    3355 non-null   int64
#  57  GK Reflexes       3355 non-null   int64
#  58  Total             3355 non-null   int64
#  59  Base Stats        3355 non-null   int64
#  60  W/F               3355 non-null   int64
#  61  SM                3355 non-null   int64
#  62  A/W               3355 non-null   int8
#  63  D/W               3355 non-null   int8
#  64  IR                3355 non-null   int64
#  65  PAC               3355 non-null   int64
#  66  SHO               3355 non-null   int64
#  67  PAS               3355 non-null   int64
#  68  DRI               3355 non-null   int64
#  69  DEF               3355 non-null   int64
#  70  PHY               3355 non-null   int64
# dtypes: datetime64[ns](1), float64(15), int64(48), int8(4), object(3)
# memory usage: 1.8+ MB

# %%
names = df.Name
remove_cols = ['Name','Team & Contract','Loan Date End','Joined','ID']
df_drop = df.drop(remove_cols,axis=1)
x = df_drop.values
scaler = preprocessing.MinMaxScaler()
x_scaled = scaler.fit_transform(x)
X_norm = pd.DataFrame(x_scaled)

# %%
pca= PCA(n_components=2)
reduced=pd.DataFrame(pca.fit_transform(X_norm))

# %%
kmeans = KMeans(n_clusters=5)
kmeans = kmeans.fit(reduced)
labels = kmeans.predict(reduced)
centroid = kmeans.cluster_centers_
clusters = kmeans.labels_.tolist()

# %%
reduced['cluster'] = clusters
reduced['name'] = df['Name']
reduced.columns = ['x','y','cluster','name']
reduced.head()
# Out:
#           x         y  cluster                   name
# 0  2.956309 -0.526959        1           G. Buffon GK
# 1 -0.447059 -0.901567        2         18 Kaká CAM CF
# 2 -0.177231 -0.828312        2   Yeremy Pino RM LM ST
# 3 -0.802515  0.093725        4               Pedri CM
# 4  3.156377 -0.486309        1         C. Kelleher GK

# %%
ax = sns.lmplot(x="x",y="y",hue='cluster',data=reduced,legend=False
                ,fit_reg=False,size=15,scatter_kws={'s':250})
texts = []

for x,y,s in zip(reduced.x,reduced.y,reduced.name):
    texts.append(plt.text(x,y,s))
ax.set(ylim=(-2,2))
plt.tick_params(labelsize=15)
plt.xlabel("PC 1",fontsize=20)
plt.ylabel("PC 2",fontsize=20)
plt.show()
# Out:
# C:\Users\senay\anaconda3\lib\site-packages\seaborn\regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
recommendations = NearestNeighbors(n_neighbors=1000,algorithm='auto')
recommendations.fit(reduced.iloc[:,:2].values)
# Out:
# NearestNeighbors(n_neighbors=1000)

# %%
similarity_indexes = recommendations.kneighbors(reduced.iloc[:,:2].values)[1]

# %%
similarity_indexes.shape
# Out:
# (3355, 1000)

# %%
reduced.shape
# Out:
# (3355, 4)

# %%
reduced.head()
# Out:
#           x         y  cluster                   name
# 0  2.956309 -0.526959        1           G. Buffon GK
# 1 -0.447059 -0.901567        2         18 Kaká CAM CF
# 2 -0.177231 -0.828312        2   Yeremy Pino RM LM ST
# 3 -0.802515  0.093725        4               Pedri CM
# 4  3.156377 -0.486309        1         C. Kelleher GK

# %%
def recommend(name,size,potential):
    index = df[df['Name']==name].index.tolist()[0]
    most_similar_indexes = similarity_indexes[index]
    if potential:
        return df.iloc[most_similar_indexes[1:],:4].where(df.Age<26).sort_values('POT',ascending=False).iloc[:size]
    else:
        return df.iloc[most_similar_indexes[1:size+1],:4]

# %%
recommend(' M. Salah RW',size=20,potential=False)
# Out:
#                        Name  Age  OVA  POT
# 175         P. Dybala CF RW   27   87   87
# 85        R. Lewandowski ST   32   92   92
# 371       Á. Di María RW LW   33   86   86
# 133         H. Son LW LM ST   28   89   89
# 326              S. Mané LW   29   89   89
# 45          K. Mbappé ST LW   22   91   95
# 1011       W. Ben Yedder ST   30   83   83
# 72         Neymar Jr LW CAM   29   91   91
# 624              H. Kane ST   27   89   89
# 32     Cristiano Ronaldo ST   36   91   91
# 92       M. Depay CF LW CAM   27   86   86
# 260      N. Fekir CAM RM ST   27   85   85
# 71         K. Benzema CF ST   33   91   91
# 16        L. Messi RW ST CF   34   93   93
# 734      S. Gnabry RM LM RW   25   86   87
# 625       R. Sterling LW RW   26   87   87
# 240    D. Mertens CF ST CAM   34   84   84
# 1162       H. Ziyech RW CAM   28   83   83
# 305        L. Sané LM RM CF   25   86   87
# 146     Gerard Moreno ST RM   29   86   86

# %%
recommend(' M. Salah RW',size=20,potential=True)
# Out:
#                        Name   Age   OVA   POT
# 45          K. Mbappé ST LW  22.0  91.0  95.0
# 3590          E. Haaland ST  20.0  88.0  94.0
# 150      P. Foden LW CAM CM  21.0  84.0  92.0
# 27     K. Havertz CAM CF ST  22.0  84.0  91.0
# 20          Vinícius Jr. LW  20.0  84.0  91.0
# 78         João Félix CF ST  21.0  83.0  91.0
# 362      M. Greenwood RM ST  19.0  79.0  90.0
# 48          F. Wirtz CAM CM  18.0  82.0  90.0
# 43             Ansu Fati LW  18.0  79.0  90.0
# 34      Ferran Torres RW ST  21.0  82.0  90.0
# 3273       09 B. Ronhaar LW  23.0  87.0  90.0
# 115      F. Chiesa RW LW RM  23.0  84.0  90.0
# 125         M. Mount CAM RW  22.0  83.0  89.0
# 52     J. Musiala LM CAM CM  18.0  78.0  89.0
# 87         A. Hakimi RB RWB  22.0  85.0  89.0
# 9            D. Vlahović ST  21.0  82.0  89.0
# 177      M. Ødegaard CAM CM  22.0  83.0  89.0
# 26            V. Osimhen ST  22.0  81.0  89.0
# 138         Oyarzabal LW RW  24.0  85.0  89.0
# 2038           19 Malcom RW  21.0  82.0  89.0
